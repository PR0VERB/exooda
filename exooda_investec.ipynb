# %%
import numpy as np
import pandas as pd
import camelot as cmt
import re
import numpy_financial as np_fin
from sklearn.preprocessing import MinMaxScaler as MMS
import tabula as tbl
# https://towardsdatascience.com/scraping-table-data-from-pdf-files-using-a-single-line-in-python-8607880c750

# %% [markdown]
# ## Later: Calculate the nearest five to the recommendation on either side then list
# ## for this we use either nearest 5 to the candidate_row or calculate the difference score for each column, as is done in this nb
# ## The reason we want to have absolute differences is that it closely resembles what the user wanted. (we don't know if higher is preferred or even better)

# %%
invest_pat = r"C:\Users\bseot\Documents\EXOODA\INVESTEC\91-IP-TFSA-List-of-Funds-en.pdf"

# %%
df_invest= cmt.read_pdf(
    invest_pat,
    pages='1-8',
    password=None,
    flavor='stream',
    suppress_stdout=False,
#     layout_kwargs={},
#     **kwargs,
)
# Out:
# UserWarning: No tables found in table area 1 [stream.py:359]
# UserWarning: No tables found in table area 2 [stream.py:359]

# %%
invest_column_names = ['FUND NAME', 'CLASS', 'TOTAL ANNUAL FEE', 'FOREIGN EXPOSURE', 'EQUITY EXPOSURE', 'PROPERTY EXPOSURE', 'Annual Growth Rate']
df_large_invest = df_invest[2].df.drop([0,1,2])
for table in df_invest[3:]:
    tab = table.df
    tab = tab.drop([0,1,2], axis = 0)
    df_large_invest = pd.concat([df_large_invest,tab],axis = 0)
np.random.seed(97)
df_large_invest['Annual Growth Rate'] = np.random.normal(loc = 0.06, scale = 0.02, size = len(df_large_invest))
df_large_invest.columns = invest_column_names

# %%
df_large_invest = df_large_invest.reset_index()
df_large_invest = df_large_invest.drop('index', axis = 1)
df_large_invest = df_large_invest.drop('CLASS', axis = 1)
df_large_invest = df_large_invest[df_large_invest['TOTAL ANNUAL FEE'] != '']

# %%
df_large_invest_crude = df_large_invest.copy()
df_large_invest_crude = df_large_invest_crude.reset_index(drop = True)
cols = df_large_invest.drop('FUND NAME', axis = 1).columns
df_large_invest[cols[:-1]] = df_large_invest[cols[:-1]].applymap(lambda x: x.replace('%',''))
df_large_invest[cols] = df_large_invest[cols].apply(pd.to_numeric, errors='coerce')
df_large_invest = df_large_invest.reset_index(drop = True)

# %%
df_large_invest_crude
# Out:
#                                       FUND NAME TOTAL ANNUAL FEE  \
# 0                Investec Cautious Managed Fund            0.85%
# 1              Investec Diversified Income Fund            0.60%
# 2                          Investec Equity Fund            1.00%
# 3                  Investec Global Franchise FF            1.10%
# 4         Investec Global Multi Asset Income FF            1.10%
# ..                                          ...              ...
# 130         STANLIB Global Balanced Feeder Fund            0.50%
# 131         STANLIB Global Property Feeder Fund            0.40%
# 132                         STANLIB Income Fund            0.60%
# 133                STANLIB Property Income Fund            1.00%
# 134  Sygnia 4th Indust Revol Global Equity Fund            0.79%
#
#     FOREIGN EXPOSURE EQUITY EXPOSURE PROPERTY EXPOSURE  Annual Growth Rate
# 0             25.00%          40.00%            15.00%            0.051408
# 1             25.00%           3.00%             5.00%            0.045072
# 2             25.00%         100.00%            10.00%            0.080137
# 3            100.00%         100.00%             0.00%            0.048178
# 4            100.00%          40.00%            10.00%            0.037453
# ..               ...             ...               ...                 ...
# 130             100%             75%                0%            0.062331
# 131             100%              0%              100%            0.043593
# 132            0.00%           0.00%             0.00%            0.083120
# 133            0.00%           0.00%           100.00%            0.074993
# 134           80.00%         100.00%             0.00%            0.076885
#
# [135 rows x 6 columns]

# %%
df_large_invest['TOTAL ANNUAL FEE'] = (df_large_invest['TOTAL ANNUAL FEE']-100)*-1

# %% [markdown]
# # Ranking

# %%
df_large_invest['Annual Growth Rate (%)'] = df_large_invest['Annual Growth Rate']
# df_large_invest = df_large_invest.drop('Annual Growth Rate', axis = 1)
df_large_invest[cols] = MMS().fit_transform(df_large_invest[cols])
df_large_invest[cols] = df_large_invest[cols]*100
df_large_invest[cols] = round(df_large_invest[cols], 2)

# %%
df_large_invest[cols] = round(df_large_invest[cols].rank(numeric_only=True, axis = 1, method = 'min')).astype(int)

# %%
df_large_invest['EScore'] = df_large_invest[cols].sum(axis = 1)

# %%
fee = input('On a scale of 1-10, how important are fees to you?')
fee = int(round(int(fee)/2, 0))

fex = input('How much foreign exposure would you like the investment to have ( in percentage terms)?')
fex = int(round(int(fex)/2, 0)/10)

eqx = input('How much equity exposure would you like the investment to have ( in percentage terms)?')
eqx = int(round(int(eqx)/2, 0)/10)

prx = input('How much property exposure would you like the investment to have ( in percentage terms)?')
prx = int(round(int(prx)/2, 0)/10)

# #for now, we just ask how nb but in future we will check the initial and end

# rat = input('What growth rate would you like your investment to have (Based on Historical performance, the highest was 10% per annum)?')
# rat = int(round(int(rat)/2, 0))

# # To Do: annuity
princ = input('What is your initial deposit amount?')
princ = int(princ)
insta = input('What will your monthly installment be?')
insta = int(insta)

n =input('For how many years would you like to keep this investment?')
n = int(n)

mat = input('To what amount would you like your investment to grow?')
mat = int(mat)
# Out:
# On a scale of 1-10, how important are fees to you?0
# How much foreign exposure would you like the investment to have ( in percentage terms)?70
# How much equity exposure would you like the investment to have ( in percentage terms)?78
# How much property exposure would you like the investment to have ( in percentage terms)?0
# What is your initial deposit amount?1000000
# What will your monthly installment be?3000
# For how many years would you like to keep this investment?4
# To what amount would you like your investment to grow?1450000

# %%
irate = np_fin.rate(nper = n*12, pmt = insta, pv = princ, fv = -mat, when='end', guess=None, tol=None, maxiter=100)

# %%
irate = irate*12

# %% [markdown]
# # Make a copy for each user then determine the best result from their difference (cell block will have a difference calculated)

# %%
ins = [fee, fex, eqx, prx, irate]
diff_cols = ['TOTAL ANNUAL FEE', 'FOREIGN EXPOSURE', 'EQUITY EXPOSURE', 'PROPERTY EXPOSURE', 'Annual Growth Rate (%)']

user_diffs = df_large_invest.copy()
for i, col_name in enumerate(diff_cols):
    user_diffs[col_name] = np.abs((user_diffs[col_name] - ins[i]))
    
user_diffs['EScore'] = user_diffs[diff_cols].sum(axis = 1)
user_diffs['EScore'] = np.abs(21 - user_diffs['EScore'])

# %%
user_diffs
# Out:
#                                       FUND NAME  TOTAL ANNUAL FEE  \
# 0                Investec Cautious Managed Fund                 5
# 1              Investec Diversified Income Fund                 5
# 2                          Investec Equity Fund                 3
# 3                  Investec Global Franchise FF                 2
# 4         Investec Global Multi Asset Income FF                 2
# ..                                          ...               ...
# 130         STANLIB Global Balanced Feeder Fund                 3
# 131         STANLIB Global Property Feeder Fund                 3
# 132                         STANLIB Income Fund                 4
# 133                STANLIB Property Income Fund                 3
# 134  Sygnia 4th Indust Revol Global Equity Fund                 2
#
#      FOREIGN EXPOSURE  EQUITY EXPOSURE  PROPERTY EXPOSURE  Annual Growth Rate  \
# 0                   1                0                  1                   4
# 1                   0                2                  2                   4
# 2                   1                2                  1                   4
# 3                   1                1                  1                   3
# 4                   2                1                  1                   3
# ..                ...              ...                ...                 ...
# 130                 2                1                  1                   2
# 131                 1                2                  4                   2
# 132                 2                2                  1                   5
# 133                 2                2                  5                   4
# 134                 1                2                  1                   3
#
#      Annual Growth Rate (%)     EScore
# 0                  0.046143  13.953857
# 1                  0.039807  11.960193
# 2                  0.074872  13.925128
# 3                  0.042913  15.957087
# 4                  0.032189  14.967811
# ..                      ...        ...
# 130                0.057066  13.942934
# 131                0.038328  10.961672
# 132                0.077855  11.922145
# 133                0.069728   8.930272
# 134                0.071620  14.928380
#
# [135 rows x 8 columns]

# %%
user_final = user_diffs.sort_values(by = 'EScore', ascending = False).iloc[:6,:]

# %%
df_large_invest_crude['EScore'] = user_diffs['EScore']
df_large_invest_crude.iloc[user_final.index.values]
# Out:
#                                         FUND NAME TOTAL ANNUAL FEE  \
# 16                              Foord Equity Fund            1.35%
# 119             Satrix MSCI World Equity Index FF            0.20%
# 104            Megafin SCI Absolute Fund of Funds            1.13%
# 12               Investec Worldwide Flexible Fund            1.10%
# 5    Investec Global Strategic Equity Feeder Fund            1.10%
# 3                    Investec Global Franchise FF            1.10%
#
#     FOREIGN EXPOSURE EQUITY EXPOSURE PROPERTY EXPOSURE  Annual Growth Rate  \
# 16            20.00%         100.00%             0.00%            0.036020
# 119          100.00%         100.00%             0.00%            0.046235
# 104           70.00%          75.00%            25.00%            0.081852
# 12           100.00%         100.00%            25.00%            0.045602
# 5            100.00%         100.00%            25.00%            0.046361
# 3            100.00%         100.00%             0.00%            0.048178
#
#         EScore
# 16   16.969245
# 119  16.959030
# 104  16.923413
# 12   15.959663
# 5    15.958903
# 3    15.957087

# %%
df_large_invest_crude.to_dict('records')
# Out:
# [{'FUND NAME': 'Investec Cautious Managed Fund',
#   'TOTAL ANNUAL FEE': '0.85%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '15.00%',
#   'Annual Growth Rate': 0.051408032919020755,
#   'EScore': 13.953856755661786},
#  {'FUND NAME': 'Investec Diversified Income Fund',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '3.00%',
#   'PROPERTY EXPOSURE': '5.00%',
#   'Annual Growth Rate': 0.04507221622845459,
#   'EScore': 11.96019257235235},
#  {'FUND NAME': 'Investec Equity Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.08013695276646879,
#   'EScore': 13.925127835814337},
#  {'FUND NAME': 'Investec Global Franchise FF',
#   'TOTAL ANNUAL FEE': '1.10%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.04817752266201059,
#   'EScore': 15.957087265918794},
#  {'FUND NAME': 'Investec Global Multi Asset Income FF',
#   'TOTAL ANNUAL FEE': '1.10%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.03745341943405187,
#   'EScore': 14.967811369146753},
#  {'FUND NAME': 'Investec Global Strategic Equity Feeder Fund',
#   'TOTAL ANNUAL FEE': '1.10%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.046361359508036055,
#   'EScore': 15.95890342907277},
#  {'FUND NAME': 'Investec High Income Fund',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.04049878487455273,
#   'EScore': 12.964766003706252},
#  {'FUND NAME': 'Investec Managed Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.07350888885408723,
#   'EScore': 12.931755899726717},
#  {'FUND NAME': 'Investec Money Market Fund',
#   'TOTAL ANNUAL FEE': '0.25%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.0548480401065098,
#   'EScore': 10.950416748474295},
#  {'FUND NAME': 'Investec Opportunity Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.05421709043032173,
#   'EScore': 13.951047698150482},
#  {'FUND NAME': 'Investec Property Equity Fund',
#   'TOTAL ANNUAL FEE': '0.85%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.05309586926478429,
#   'EScore': 8.952168919316021},
#  {'FUND NAME': 'Investec Value Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.02629802334044405,
#   'EScore': 13.978966765240362},
#  {'FUND NAME': 'Investec Worldwide Flexible Fund',
#   'TOTAL ANNUAL FEE': '1.10%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.04560192893745823,
#   'EScore': 15.959662859643347},
#  {'FUND NAME': 'Allan Gray Tax Free Balanced Fund',
#   'TOTAL ANNUAL FEE': '1.05%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.04951327488234641,
#   'EScore': 13.95575151369846},
#  {'FUND NAME': 'Coronation Strategic Income Fund',
#   'TOTAL ANNUAL FEE': '0.45%',
#   'FOREIGN EXPOSURE': '10.00%',
#   'EQUITY EXPOSURE': '10.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.08851418121288418,
#   'EScore': 11.916750607367922},
#  {'FUND NAME': 'Foord Balanced Fund',
#   'TOTAL ANNUAL FEE': '1.35%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.07664940740366095,
#   'EScore': 15.928615381177144},
#  {'FUND NAME': 'Foord Equity Fund',
#   'TOTAL ANNUAL FEE': '1.35%',
#   'FOREIGN EXPOSURE': '20.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.03601963248582428,
#   'EScore': 16.96924515609498},
#  {'FUND NAME': 'Foord Flexible Fund',
#   'TOTAL ANNUAL FEE': '1.35%',
#   'FOREIGN EXPOSURE': '70.00%',
#   'EQUITY EXPOSURE': '90.00%',
#   'PROPERTY EXPOSURE': '20.00%',
#   'Annual Growth Rate': 0.05304784903232409,
#   'EScore': 14.952216939548482},
#  {'FUND NAME': 'Nedgroup Inv Flexible Income Fund',
#   'TOTAL ANNUAL FEE': '0.50%',
#   'FOREIGN EXPOSURE': '20.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '20.00%',
#   'Annual Growth Rate': 0.04045581599724257,
#   'EScore': 10.964808972583562},
#  {'FUND NAME': 'Nedgroup Inv Global Equity FF',
#   'TOTAL ANNUAL FEE': '1.10%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.07075752991953255,
#   'EScore': 15.934507258661274},
#  {'FUND NAME': 'Nedgroup Inv Global Flexible FF',
#   'TOTAL ANNUAL FEE': '1.10%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.06335212276446563,
#   'EScore': 14.94191266581634},
#  {'FUND NAME': 'Nedgroup Inv Managed Fund',
#   'TOTAL ANNUAL FEE': '1.10%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.05214434576886266,
#   'EScore': 15.953120442811944},
#  {'FUND NAME': 'Nedgroup Inv Rainmaker Fund',
#   'TOTAL ANNUAL FEE': '1.10%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.05561079977389781,
#   'EScore': 11.949653988806908},
#  {'FUND NAME': 'Nedgroup Inv Stable Fund',
#   'TOTAL ANNUAL FEE': '0.95%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.056431718894631944,
#   'EScore': 13.948833069686174},
#  {'FUND NAME': 'Nedgroup Inv Value Fund',
#   'TOTAL ANNUAL FEE': '1.10%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.07136884446813319,
#   'EScore': 11.933895944112672},
#  {'FUND NAME': 'Old Mutual Real Income Fund',
#   'TOTAL ANNUAL FEE': '0.80%',
#   'FOREIGN EXPOSURE': '10.00%',
#   'EQUITY EXPOSURE': '25.00%',
#   'PROPERTY EXPOSURE': '15.00%',
#   'Annual Growth Rate': 0.06325975515154292,
#   'EScore': 12.942005033429263},
#  {'FUND NAME': 'Old Mutual SA Quoted Property Fund',
#   'TOTAL ANNUAL FEE': '0.85%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.08085417401990012,
#   'EScore': 8.924410614560905},
#  {'FUND NAME': 'Prescient Income Provider Fund',
#   'TOTAL ANNUAL FEE': '0.50%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '10.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.07090052535346315,
#   'EScore': 10.934364263227343},
#  {'FUND NAME': 'Prudential Balanced Fund',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.0344455669119703,
#   'EScore': 11.970819221668835},
#  {'FUND NAME': 'Prudential Inflation Plus Fund',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.05978354141828356,
#   'EScore': 12.94548124716252},
#  {'FUND NAME': 'PSG Balanced Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.06702939892394771,
#   'EScore': 13.938235389656857},
#  {'FUND NAME': 'PSG Equity Fund',
#   'TOTAL ANNUAL FEE': '1.20%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.06947817968099683,
#   'EScore': 15.935786608899807},
#  {'FUND NAME': 'Rezco Value Trend Fund',
#   'TOTAL ANNUAL FEE': '0.65%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.07238684193334811,
#   'EScore': 13.932877946647457},
#  {'FUND NAME': 'SIM Active Income Fund',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '5.00%',
#   'Annual Growth Rate': 0.057483958360942576,
#   'EScore': 12.947780830219862},
#  {'FUND NAME': 'STANLIB Balanced Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.06072805686514973,
#   'EScore': 13.944536731715655},
#  {'FUND NAME': 'ABSA Absolute Fund',
#   'TOTAL ANNUAL FEE': '0.85%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '20.00%',
#   'Annual Growth Rate': 0.032277434154928814,
#   'EScore': 12.972987354425877},
#  {'FUND NAME': 'ABSA Balanced Fund',
#   'TOTAL ANNUAL FEE': '0.85%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '65.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.0755063463571875,
#   'EScore': 14.929758442223617},
#  {'FUND NAME': 'ABSA Global Value Feeder Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.060801014491062615,
#   'EScore': 15.944463774089742},
#  {'FUND NAME': 'ABSA Property Equity Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '10.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.01922493234489881,
#   'EScore': 10.986039856235907},
#  {'FUND NAME': 'ABSA Select Equity Fund',
#   'TOTAL ANNUAL FEE': '0.85%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.037295117502066974,
#   'EScore': 10.967969671078738},
#  {'FUND NAME': 'Aylett Balanced Prescient Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.08759583110733883,
#   'EScore': 13.917668957473467},
#  {'FUND NAME': 'Aylett Equity Prescient  Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.05908819762359223,
#   'EScore': 13.946176590957213},
#  {'FUND NAME': 'Anchor BCI Equity Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.04159844653636127,
#   'EScore': 12.963666342044444},
#  {'FUND NAME': 'Anchor BCI Flexible Income Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '10.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.08966131152158238,
#   'EScore': 11.915603477059223},
#  {'FUND NAME': 'Anchor BCI Worldwide Flexible Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.03161528074622263,
#   'EScore': 13.973649507834583},
#  {'FUND NAME': 'BCI Best Blend Flexible Income Fund',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '10.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.05242893770216065,
#   'EScore': 10.952835850878644},
#  {'FUND NAME': 'BCI Fundsmith Equity Feeder Fund',
#   'TOTAL ANNUAL FEE': '0.40%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '5.00%',
#   'Annual Growth Rate': 0.05467694281870117,
#   'EScore': 14.950587845762104},
#  {'FUND NAME': 'BCI Income Plus Fund',
#   'TOTAL ANNUAL FEE': '0.50%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.06955136707487952,
#   'EScore': 12.935713421505925},
#  {'FUND NAME': 'Reitway BCI Global Property Fund',
#   'TOTAL ANNUAL FEE': '0.95%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '30.00%',
#   'Annual Growth Rate': 0.019164473150134753,
#   'EScore': 13.98610031543067},
#  {'FUND NAME': 'Select BCI Balanced Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '60.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.07000557602261685,
#   'EScore': 13.935259212558188},
#  {'FUND NAME': 'Sesfikile BCI Property Fund',
#   'TOTAL ANNUAL FEE': '0.90%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.05181403696363688,
#   'EScore': 8.953450751617169},
#  {'FUND NAME': 'Bridge High Income Fund',
#   'TOTAL ANNUAL FEE': '0.65%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '20.00%',
#   'Annual Growth Rate': 0.07649504526668834,
#   'EScore': 12.928769743314117},
#  {'FUND NAME': 'Bridge Managed Growth Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '5.00%',
#   'EQUITY EXPOSURE': '65.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.06415264196518929,
#   'EScore': 11.941112146615616},
#  {'FUND NAME': 'Bridge Stable Growth Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '5.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.048526370303278554,
#   'EScore': 10.956738418277526},
#  {'FUND NAME': 'Analytics Ci Balanced Fund of Funds',
#   'TOTAL ANNUAL FEE': '0.65%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '15.00%',
#   'Annual Growth Rate': 0.07749366908512295,
#   'EScore': 13.927771119495683},
#  {'FUND NAME': 'Analytics Ci Cautious Fund of Funds',
#   'TOTAL ANNUAL FEE': '0.65%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '15.00%',
#   'Annual Growth Rate': 0.06025481356852628,
#   'EScore': 13.94500997501228},
#  {'FUND NAME': 'Analytics Ci Moderate Fund of Funds',
#   'TOTAL ANNUAL FEE': '0.65%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '65.00%',
#   'PROPERTY EXPOSURE': '15.00%',
#   'Annual Growth Rate': 0.028604391964795327,
#   'EScore': 12.97666039661601},
#  {'FUND NAME': 'Coronation Global Strategic USD Income [ZAR] FF',
#   'TOTAL ANNUAL FEE': '0.70%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '10.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.044577220311940474,
#   'EScore': 11.960687568268865},
#  {'FUND NAME': 'Kagiso Balanced Fund',
#   'TOTAL ANNUAL FEE': '0.85%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.06521778207355435,
#   'EScore': 12.940047006507251},
#  {'FUND NAME': 'Kagiso Islamic Balanced Fund',
#   'TOTAL ANNUAL FEE': '0.85%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.09696875047938265,
#   'EScore': 14.908296038101422},
#  {'FUND NAME': 'Kagiso Islamic Equity Fund',
#   'TOTAL ANNUAL FEE': '0.85%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.04017555503209243,
#   'EScore': 12.965089233548714},
#  {'FUND NAME': 'Kagiso Protector Fund',
#   'TOTAL ANNUAL FEE': '0.85%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '50.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.09038042476474634,
#   'EScore': 14.914884363816059},
#  {'FUND NAME': 'Kagiso Stable Fund',
#   'TOTAL ANNUAL FEE': '0.85%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.03075086517658731,
#   'EScore': 13.974513923404217},
#  {'FUND NAME': 'Marriott Core Income Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.08287006133116709,
#   'EScore': 11.922394727249639},
#  {'FUND NAME': 'Marriott Dividend Growth Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.04234518752741688,
#   'EScore': 10.962919601053388},
#  {'FUND NAME': 'Marriott International Growth Feeder Fund',
#   'TOTAL ANNUAL FEE': '1.25%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.063003137093431,
#   'EScore': 15.942261651487375},
#  {'FUND NAME': 'Marriott International Real Estate Fund',
#   'TOTAL ANNUAL FEE': '1.25%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.06696901219491698,
#   'EScore': 11.938295776385889},
#  {'FUND NAME': 'Marriott Property Equity Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.04842373321855517,
#   'EScore': 7.956841055362251},
#  {'FUND NAME': 'Marriott Property Income Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.028334584850653467,
#   'EScore': 7.976930203730152},
#  {'FUND NAME': 'Nedgroup Investments Balanced Fund',
#   'TOTAL ANNUAL FEE': '0.65%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.060017703385757806,
#   'EScore': 11.945247085195048},
#  {'FUND NAME': 'Nedgroup Investments Core Diversified Fund',
#   'TOTAL ANNUAL FEE': '0.35%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.0985352505631778,
#   'EScore': 14.906729538017627},
#  {'FUND NAME': 'Nedgroup Investments Opportunity Fund',
#   'TOTAL ANNUAL FEE': '0.95%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '60.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.030860714746070862,
#   'EScore': 11.974404073834734},
#  {'FUND NAME': 'Nedgroup Investments Property Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '10.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.05278442240776384,
#   'EScore': 8.952480366173042},
#  {'FUND NAME': 'Novare Balanced Fund',
#   'TOTAL ANNUAL FEE': '0.65%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.09761620686350395,
#   'EScore': 13.9076485817173},
#  {'FUND NAME': 'Novare Capital Preserver Fund of Funds',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.06700294231697992,
#   'EScore': 13.938261846263824},
#  {'FUND NAME': 'Novare Worldwide Flexible Fund of Funds',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.037822013405094,
#   'EScore': 12.96744277517571},
#  {'FUND NAME': 'Catalyst Global Real Estate Prescient Feeder Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.03125752724016462,
#   'EScore': 7.97400726134064},
#  {'FUND NAME': 'ClucasGray Equilibrium Prescient Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '55.00%',
#   'PROPERTY EXPOSURE': '15.00%',
#   'Annual Growth Rate': 0.07610807746676156,
#   'EScore': 14.929156711114043},
#  {'FUND NAME': 'ClucasGray Equity Prescient Fund A',
#   'TOTAL ANNUAL FEE': '0.90%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.04359993793191716,
#   'EScore': 11.961664850648887},
#  {'FUND NAME': 'ClucasGray Future Titans Fund',
#   'TOTAL ANNUAL FEE': '0.90%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '95.00%',
#   'PROPERTY EXPOSURE': '20.00%',
#   'Annual Growth Rate': 0.048627595285963984,
#   'EScore': 12.95663719329484},
#  {'FUND NAME': 'Dalebrook Equity Prescient Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.0854566922673683,
#   'EScore': 12.919808096313437},
#  {'FUND NAME': 'Prescient Balanced Fund',
#   'TOTAL ANNUAL FEE': '0.30%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '15.00%',
#   'Annual Growth Rate': 0.08386376751499892,
#   'EScore': 13.921401021065806},
#  {'FUND NAME': 'Prescient Positive Return QuantPlus Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.03909980247764802,
#   'EScore': 10.966164986103157},
#  {'FUND NAME': 'Prescient Yield QuantPlus Fund',
#   'TOTAL ANNUAL FEE': '0.40%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.0833381861499708,
#   'EScore': 10.921926602430835},
#  {'FUND NAME': 'Seed Balanced Prescient Fund',
#   'TOTAL ANNUAL FEE': '1.35%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '60.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.06359025121390903,
#   'EScore': 14.941674537366897},
#  {'FUND NAME': 'Autus Prime Income Plus Fund',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.02972315966985095,
#   'EScore': 13.975541628910953},
#  {'FUND NAME': 'Autus Prime Property Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '10.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.034963754406711824,
#   'EScore': 9.970301034174094},
#  {'FUND NAME': 'Prudential Enhanced Income Fund',
#   'TOTAL ANNUAL FEE': '0.50%',
#   'FOREIGN EXPOSURE': '20.00%',
#   'EQUITY EXPOSURE': '10.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.04262564842218543,
#   'EScore': 9.96263914015862},
#  {'FUND NAME': 'Prudential Enhanced SA Property Tracker',
#   'TOTAL ANNUAL FEE': '0.55%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.03732947606493936,
#   'EScore': 7.967935312515866},
#  {'FUND NAME': 'PSG Diversified Income Fund',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '20.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.08036175260211369,
#   'EScore': 14.92490303597869},
#  {'FUND NAME': 'PSG Multi-Man Cautious FoF',
#   'TOTAL ANNUAL FEE': '0.50%',
#   'FOREIGN EXPOSURE': '24.90%',
#   'EQUITY EXPOSURE': '37.80%',
#   'PROPERTY EXPOSURE': '4.10%',
#   'Annual Growth Rate': 0.05212254915268155,
#   'EScore': 13.953142239428123},
#  {'FUND NAME': 'PSG Multi-Man Equity FoF',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '17.30%',
#   'EQUITY EXPOSURE': '94.40%',
#   'PROPERTY EXPOSURE': '1.80%',
#   'Annual Growth Rate': 0.07532642929255688,
#   'EScore': 13.929938359288247},
#  {'FUND NAME': 'PSG Stable Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.060805018225167366,
#   'EScore': 13.944459770355639},
#  {'FUND NAME': 'Rezco Managed Plus Fund',
#   'TOTAL ANNUAL FEE': '1.05%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '20.00%',
#   'Annual Growth Rate': 0.052630633741829844,
#   'EScore': 13.952634154838975},
#  {'FUND NAME': 'Rezco Stable Fund',
#   'TOTAL ANNUAL FEE': '0.85%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.0349259367638019,
#   'EScore': 11.970338851817003},
#  {'FUND NAME': 'Element Balanced SCI Fund',
#   'TOTAL ANNUAL FEE': '0.90%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.05426121365839405,
#   'EScore': 13.95100357492241},
#  {'FUND NAME': 'Element Earth Equity SCI Fund',
#   'TOTAL ANNUAL FEE': '0.90%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.03911757940747214,
#   'EScore': 12.966147209173332},
#  {'FUND NAME': 'Element Flexible SCI Fund',
#   'TOTAL ANNUAL FEE': '0.90%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.057218099604045745,
#   'EScore': 15.94804668897676},
#  {'FUND NAME': 'Element Global Equity SCI Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.06955415648118984,
#   'EScore': 12.935710632099616},
#  {'FUND NAME': 'Element Islamic Balanced SCI Fund',
#   'TOTAL ANNUAL FEE': '0.90%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.07314910869120483,
#   'EScore': 13.9321156798896},
#  {'FUND NAME': 'Element Islamic Equity SCI Fund',
#   'TOTAL ANNUAL FEE': '0.90%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.09304785723282033,
#   'EScore': 13.912216931347984},
#  {'FUND NAME': 'Element Islamic Global SCI Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.0374686062484807,
#   'EScore': 12.967796182332325},
#  {'FUND NAME': 'Element Real Income SCI Fund',
#   'TOTAL ANNUAL FEE': '0.65%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.036523375341062675,
#   'EScore': 13.968741413239742},
#  {'FUND NAME': 'First Avenue SCI Equity Fund',
#   'TOTAL ANNUAL FEE': '0.90%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.042710586179481286,
#   'EScore': 11.962554202401323},
#  {'FUND NAME': 'Megafin SCI Absolute Fund of Funds',
#   'TOTAL ANNUAL FEE': '1.13%',
#   'FOREIGN EXPOSURE': '70.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.08185207929967793,
#   'EScore': 16.923412709281127},
#  {'FUND NAME': 'Megafin SCI Balanced Fund of Funds',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '40.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.07323711188416138,
#   'EScore': 13.932027676696643},
#  {'FUND NAME': 'Megafin SCI Income Fund of Funds',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '70.00%',
#   'EQUITY EXPOSURE': '10.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.030477347146036532,
#   'EScore': 9.974787441434769},
#  {'FUND NAME': 'Megafin SCI Stable Fund of Funds',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '20.00%',
#   'Annual Growth Rate': 0.0349022682761012,
#   'EScore': 13.970362520304704},
#  {'FUND NAME': 'Northstar SCI Income Fund',
#   'TOTAL ANNUAL FEE': '0.86%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.033199030799186444,
#   'EScore': 10.97206575778162},
#  {'FUND NAME': 'SIM Active Income Fund B4',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '20.00%',
#   'Annual Growth Rate': 0.09271048183847391,
#   'EScore': 9.912554306742331},
#  {'FUND NAME': 'SIM Inflation Plus Fund',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.08589130251670493,
#   'EScore': 13.9193734860641},
#  {'FUND NAME': 'Truffle SCI Flexible Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.05390945318062204,
#   'EScore': 10.951355335400184},
#  {'FUND NAME': 'Truffle SCI General Equity Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '00.00%',
#   'Annual Growth Rate': 0.036260448945895606,
#   'EScore': 13.96900433963491},
#  {'FUND NAME': 'Satrix Balanced Index Fund',
#   'TOTAL ANNUAL FEE': '0.25%',
#   'FOREIGN EXPOSURE': '20.00%',
#   'EQUITY EXPOSURE': '70.00%',
#   'PROPERTY EXPOSURE': '6.00%',
#   'Annual Growth Rate': 0.0952951983072502,
#   'EScore': 13.909969590273555},
#  {'FUND NAME': 'Satrix Bond Index Fund',
#   'TOTAL ANNUAL FEE': '0.25%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.07020670200036362,
#   'EScore': 10.935058086580442},
#  {'FUND NAME': 'Satrix Dividend+ Index Fund',
#   'TOTAL ANNUAL FEE': '0.25%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.016314956955307096,
#   'EScore': 11.988949831625497},
#  {'FUND NAME': 'Satrix Equally Weighted Top 40 Index Fund',
#   'TOTAL ANNUAL FEE': '0.25%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.04445458033670456,
#   'EScore': 11.960810208244101},
#  {'FUND NAME': 'Satrix Low Equity Balanced Index Fund',
#   'TOTAL ANNUAL FEE': '0.25%',
#   'FOREIGN EXPOSURE': '20.00%',
#   'EQUITY EXPOSURE': '35.00%',
#   'PROPERTY EXPOSURE': '5.00%',
#   'Annual Growth Rate': 0.07035534892218513,
#   'EScore': 13.93490943965862},
#  {'FUND NAME': 'Satrix Momentum Index Fund',
#   'TOTAL ANNUAL FEE': '0.35%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.0385694459767915,
#   'EScore': 11.966695342604014},
#  {'FUND NAME': 'Satrix MSCI World Equity Index FF',
#   'TOTAL ANNUAL FEE': '0.20%',
#   'FOREIGN EXPOSURE': '100.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.046234635260162325,
#   'EScore': 16.959030153320644},
#  {'FUND NAME': 'Satrix Property Index Fund',
#   'TOTAL ANNUAL FEE': '0.25%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.0654184918111115,
#   'EScore': 7.939846296769694},
#  {'FUND NAME': 'Satrix Quality Index Fund',
#   'TOTAL ANNUAL FEE': '0.35%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.04394729644165013,
#   'EScore': 11.961317492139155},
#  {'FUND NAME': 'Satrix RAFi 40 Index Fund',
#   'TOTAL ANNUAL FEE': '0.35%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.10071552253064991,
#   'EScore': 13.904549266050156},
#  {'FUND NAME': 'Satrix Top 40 Index Fund',
#   'TOTAL ANNUAL FEE': '0.25%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.0755214680284128,
#   'EScore': 11.929743320552392},
#  {'FUND NAME': 'STANLIB Absolute Plus Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '75.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.08323955330607113,
#   'EScore': 14.922025235274734},
#  {'FUND NAME': 'STANLIB Aggressive Income Fund',
#   'TOTAL ANNUAL FEE': '0.90%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.05691353150719706,
#   'EScore': 11.948351257073607},
#  {'FUND NAME': 'STANLIB Balanced Cautious Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '25.00%',
#   'EQUITY EXPOSURE': '40.00%',
#   'PROPERTY EXPOSURE': '25.00%',
#   'Annual Growth Rate': 0.038886948109415787,
#   'EScore': 11.96637784047139},
#  {'FUND NAME': 'STANLIB Equity Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '30.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '10.00%',
#   'Annual Growth Rate': 0.05833665859393155,
#   'EScore': 13.946928129986873},
#  {'FUND NAME': 'STANLIB Flexible Income Fund',
#   'TOTAL ANNUAL FEE': '0.75%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.048318785688586594,
#   'EScore': 10.956946002892218},
#  {'FUND NAME': 'STANLIB Global Balanced Cautious Feeder Fund',
#   'TOTAL ANNUAL FEE': '0.50%',
#   'FOREIGN EXPOSURE': '100%',
#   'EQUITY EXPOSURE': '40%',
#   'PROPERTY EXPOSURE': '0%',
#   'Annual Growth Rate': 0.05662568965965621,
#   'EScore': 12.948639098921149},
#  {'FUND NAME': 'STANLIB Global Balanced Feeder Fund',
#   'TOTAL ANNUAL FEE': '0.50%',
#   'FOREIGN EXPOSURE': '100%',
#   'EQUITY EXPOSURE': '75%',
#   'PROPERTY EXPOSURE': '0%',
#   'Annual Growth Rate': 0.062330936037514925,
#   'EScore': 13.942933852543291},
#  {'FUND NAME': 'STANLIB Global Property Feeder Fund',
#   'TOTAL ANNUAL FEE': '0.40%',
#   'FOREIGN EXPOSURE': '100%',
#   'EQUITY EXPOSURE': '0%',
#   'PROPERTY EXPOSURE': '100%',
#   'Annual Growth Rate': 0.04359298521578281,
#   'EScore': 10.961671803365022},
#  {'FUND NAME': 'STANLIB Income Fund',
#   'TOTAL ANNUAL FEE': '0.60%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.08311967596979511,
#   'EScore': 11.92214511261101},
#  {'FUND NAME': 'STANLIB Property Income Fund',
#   'TOTAL ANNUAL FEE': '1.00%',
#   'FOREIGN EXPOSURE': '0.00%',
#   'EQUITY EXPOSURE': '0.00%',
#   'PROPERTY EXPOSURE': '100.00%',
#   'Annual Growth Rate': 0.07499316223252553,
#   'EScore': 8.93027162634828},
#  {'FUND NAME': 'Sygnia 4th Indust Revol Global Equity Fund',
#   'TOTAL ANNUAL FEE': '0.79%',
#   'FOREIGN EXPOSURE': '80.00%',
#   'EQUITY EXPOSURE': '100.00%',
#   'PROPERTY EXPOSURE': '0.00%',
#   'Annual Growth Rate': 0.07688466645222095,
#   'EScore': 14.928380122128583}]

# %% [markdown]
# What is the future value after 10 years of saving $200 now, with an additional monthly savings of $200. Assume the interest rate is 6% (annually) compounded monthly?

# %%
# TOTALANNUALFEE = df_large_invest.sort_values(by = 'TOTAL ANNUAL FEE', ascending = False)[['FUND NAME','TOTAL ANNUAL FEE']]
# FOREIGNEXPOSURE = df_large_invest.sort_values(by = 'FOREIGN EXPOSURE', ascending = False)[['FUND NAME','FOREIGN EXPOSURE']]
# EQUITYEXPOSURE = df_large_invest.sort_values(by = 'EQUITY EXPOSURE', ascending = False)[['FUND NAME','EQUITY EXPOSURE']]
# PROPERTYEXPOSURE = df_large_invest.sort_values(by = 'PROPERTY EXPOSURE', ascending = False)[['FUND NAME','PROPERTY EXPOSURE']]

# %% [markdown]
# # Run app. Main app is exooda_invest.py

# %%
import dash_core_components as dcc
import dash_html_components as html
import dash
from dash.dependencies import Input, Output

app = dash.Dash(__name__)
app.layout = html.Div(
    [
        dcc.Input(id="dfalse", type="number", placeholder="Debounce False"),
        dcc.Input(
            id="dtrue", type="number",
            debounce=True, placeholder="Debounce True",
        ),
        dcc.Input(
            id="input_range", type="number", placeholder="input with range",
            min=10, max=100, step=3,
        ),
        html.Hr(),
        html.Div(id="number-out"),
    ]
)


@app.callback(
    Output("number-out", "children"),
    [Input("dfalse", "value"), Input("dtrue", "value"), Input("input_range", "value")],
)
def number_render(fval, tval, rangeval):
    return "dfalse: {}, dtrue: {}, range: {}".format(fval, tval, rangeval)


if __name__ == "__main__":
    app.run_server(debug=True)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\bseot\anaconda3\envs\exoodaEnv\lib\site-packages\IPython\core\interactiveshell.py:3426: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
